# %%
from collections import defaultdict
from itertools import count
import matplotlib.pyplot as plt
from metaphone import doublemetaphone
import pandas as pd
from statistics import mean
import textdistance
import os
import numpy as np

from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import precision_recall_curve, f1_score, precision_score, recall_score
from sklearn.model_selection import cross_val_predict, cross_validate, StratifiedKFold

from matplotlib_venn import venn2, venn2_circles, venn2_unweighted
from matplotlib_venn import venn3, venn3_circles

from metaphone import doublemetaphone
import jellyfish

import sys
# Add the ptdraft folder path to the sys.path list
sys.path.append('..')

from model import Siamese
from process import load_data, load_json_config, str2emb

# %% [markdown]
# # Parameters:

# %%
# Trained folder: contrains all of the information about the run. and how the DL model predicted it.
trained_folder = "../results/gru_soundex"

# results path
csv_save_path = "../results/"

# Best Save for the Run:
run_name = "gru_soundex"
DL_thrsholds = [0.778285384,0.79654932,0.794194341,0.783809662,0.772859931]

# Config file:
config_file = "../configs/gru_soundex.json"

# Phonetic RF addition
phonetic_RF = True

# Result Set: {1800s_ln, 1800s_fn or Normal}:
result_set = "Normal"

# %%
# Helper functions:
def compare_dm1(s1, s2):
    return textdistance.levenshtein.normalized_similarity(doublemetaphone(s1)[0],doublemetaphone(s2)[0])

def compare_dm2(s1, s2):
    return textdistance.levenshtein.normalized_similarity(doublemetaphone(s1)[1],doublemetaphone(s2)[1])

# MAX VALUE for RF
vowel_max = 6
consonant_max = 13
character_max = 19

def create_RF_features(dataframe):
    dataframe['levenshtein'] = [textdistance.levenshtein.normalized_similarity(x, y) for x, y in dataframe[['name_a', 'name_b']].itertuples(index=False)]
    dataframe['jaro'] = [textdistance.jaro.normalized_similarity(x, y) for x, y in dataframe[['name_a', 'name_b']].itertuples(index=False)]
    dataframe['jaro_winkler'] = [textdistance.jaro_winkler.normalized_similarity(x, y) for x, y in dataframe[['name_a', 'name_b']].itertuples(index=False)]
    dataframe['jaccard'] = [textdistance.jaccard.normalized_similarity(x, y) for x, y in dataframe[['name_a', 'name_b']].itertuples(index=False)]
    dataframe['sorensen_dice'] = [textdistance.sorensen_dice.normalized_similarity(x, y) for x, y in dataframe[['name_a', 'name_b']].itertuples(index=False)]
    dataframe['dm1'] = [compare_dm1(x, y) for x, y in dataframe[['name_a', 'name_b']].itertuples(index=False)]
    dataframe['dm2'] = [compare_dm2(x, y) for x, y in dataframe[['name_a', 'name_b']].itertuples(index=False)]
    dataframe['vowels_a'] = dataframe['name_a'].apply(lambda x: sum(map(x.count, 'aeiou')))
    dataframe['vowels_b'] = dataframe['name_b'].apply(lambda x: sum(map(x.count, 'aeiou')))
    dataframe['consonants_a'] = dataframe['name_a'].str.len() - dataframe['vowels_a']
    dataframe['consonants_b'] = dataframe['name_b'].str.len() - dataframe['vowels_b']
    dataframe['vowels'] = (dataframe['vowels_a'] - dataframe['vowels_b']).abs()
    dataframe['vowels'] = 1 - (dataframe['vowels'] / vowel_max)
    dataframe['consonants'] = (dataframe['consonants_a'] - dataframe['consonants_b']).abs()
    dataframe['consonants'] = 1 - (dataframe['consonants'] / consonant_max)
    dataframe['characters'] = (dataframe['name_a'].str.len() - dataframe['name_b'].str.len()).abs()
    dataframe['characters'] = 1 - (dataframe['characters'] / character_max)

    #Phonetic Component:
    dataframe["levenshtein_phonetic"] = [textdistance.levenshtein.normalized_similarity(jellyfish.soundex(x), jellyfish.soundex(y)) for x, y in dataframe[['name_a', 'name_b']].itertuples(index=False)]
    dataframe["jw_phonetic"] = [textdistance.jaro_winkler.normalized_similarity(jellyfish.soundex(x), jellyfish.soundex(y)) for x, y in dataframe[['name_a', 'name_b']].itertuples(index=False)]

    dataframe = dataframe.drop(columns=['vowels_a', 'vowels_b', 'consonants_a', 'consonants_b'])
    
    return dataframe

# %% [markdown]
# # 1. Get the dataset and folds from trained folder

# %%
folds = []

for i in range(5):
  test_csv = os.path.join(trained_folder, f"test_k{i}.csv")
  df = pd.read_csv(test_csv, usecols=["name1", "name2", "label"])
  df = df.astype({"label": bool, "name1": str, "name2": str})
  df = df.rename(columns={"name1": "name_a", "name2": "name_b"})

  folds.append(df)

len(folds)

folds[0]
# Out:
#           name_a      name_b  label
# 0        dessell     pessall  False
# 1        ellgood      elwood  False
# 2         ermann       erman   True
# 3         koland     nowland  False
# 4       radebach     rasbach  False
# ...          ...         ...    ...
# 14995   tildsley     bertini  False
# 14996      rieck        riek  False
# 14997    dippery     brohart  False
# 14998  wipperman  wippermann   True
# 14999  utteridge    uttridge   True
#
# [15000 rows x 3 columns]

# %% [markdown]
# # 2. Train the RF model

# %%
out_pairs = []

for pairs in folds:
    out_pairs.append(create_RF_features(pairs))
    
folds = out_pairs
    
scores = defaultdict(list)
y_prob = []
name_a = []
name_b = []
labels = []

rf_y_pred = []

rf_models = []

for test_fold_index in range(len(folds)):
    val_fold_index = test_fold_index - 1 if test_fold_index - 1 >= 0 else len(folds) - 1

    X_train = pd.DataFrame()
    y_train = pd.Series(dtype=bool)
    for fold_index in range(len(folds)):
        if fold_index != test_fold_index and fold_index != val_fold_index:
            X_train = pd.concat([X_train, folds[fold_index].drop(columns=['name_a', 'name_b', 'label'])])
            y_train = pd.concat([y_train, folds[fold_index]['label']])
    name_a = name_a + folds[test_fold_index]["name_a"].values.tolist()
    name_b = name_b + folds[test_fold_index]["name_b"].values.tolist()
    X_test = folds[test_fold_index].drop(columns=['name_a', 'name_b', 'label'])
    y_test = folds[test_fold_index]['label']
    
    clf = RandomForestClassifier(random_state=0)
    
    clf.fit(X_train, y_train)
    
    y_pred = clf.predict(X_test)

    rf_y_pred += np.array(y_pred).tolist()

    scores['test_precision'].append(precision_score(y_test, y_pred))
    scores['test_recall'].append(recall_score(y_test, y_pred))
    scores['f1_score'].append(f1_score(y_test, y_pred))

    yt = np.array(y_test)
    yp = np.array(y_pred)

    to_labels = yt.astype(int).tolist()
    labels = labels + to_labels

    scores['tp'].append(np.count_nonzero(yt & yp))
    scores['tn'].append(np.count_nonzero(np.logical_not(yt) & np.logical_not(yp)))
    scores['fp'].append(np.count_nonzero(np.logical_not(yt) & yp))
    scores['fn'].append(np.count_nonzero(yt & np.logical_not(yp)))

    y_prob += [x[1] for x in clf.predict_proba(X_test)]

    rf_models.append(clf)

print({k: mean(v) for k, v in scores.items()})
# Out:
# {'test_precision': 0.9030918765344335, 'test_recall': 0.93076, 'f1_score': 0.9167086101343502, 'tp': 4653.8, 'tn': 9500.6, 'fp': 499.4, 'fn': 346.2}

# %% [markdown]
# # 3. Load the best DF models

# %%
dl_models = []

for k in range(5):
    save_file = os.path.join("../saves", f"{run_name}_k{k}_BEST")

    json_file = os.path.join("configs", str(run_name) + ".json")
    DATASET_CONFIG, TRAIN_CONFIG, MODEL_KWARGS = load_json_config(config_file)

    _, model, _, _, _, _, _ = load_data(save_file, TRAIN_CONFIG, MODEL_KWARGS)
    dl_models.append(model)
    
print(dl_models)
# Out:
# Loaded run successfully from ../saves/gru_soundex_k0_BEST
# Loaded run successfully from ../saves/gru_soundex_k1_BEST
# Loaded run successfully from ../saves/gru_soundex_k2_BEST
# Loaded run successfully from ../saves/gru_soundex_k3_BEST
# Loaded run successfully from ../saves/gru_soundex_k4_BEST
# [Siamese(
#   (A_function): GRU(36, 25, num_layers=8, batch_first=True, bidirectional=True)
#   (bidirectional_linear): Linear(in_features=3050, out_features=25, bias=True)
# ), Siamese(
#   (A_function): GRU(36, 25, num_layers=8, batch_first=True, bidirectional=True)
#   (bidirectional_linear): Linear(in_features=3050, out_features=25, bias=True)
# ), Siamese(
#   (A_function): GRU(36, 25, num_layers=8, batch_first=True, bidirectional=True)
#   (bidirectional_linear): Linear(in_features=3050, out_features=25, bias=True)
# ), Siamese(
#   (A_function): GRU(36, 25, num_layers=8, batch_first=True, bidirectional=True)
#   (bidirectional_linear): Linear(in_features=3050, out_features=25, bias=True)
# ), Siamese(
#   (A_function): GRU(36, 25, num_layers=8, batch_first=True, bidirectional=True)
#   (bidirectional_linear): Linear(in_features=3050, out_features=25, bias=True)
# )]

# %% [markdown]
# # 4. Get the Results set

# %%
def get_1800s_ln_results_set(path = "../data/1800s_last_name_pairs.tsv"):
    df = pd.read_csv(path, delimiter = "\t", names = ["name0", "name1"])
    df["gt_label"] = 1
    
    return df

def get_1800s_fn_results_set(path = "../data/1800s_first_name_pairs.tsv"):
    df = pd.read_csv(path, delimiter = "\t", names = ["name0", "name1"])
    df["gt_label"] = 1
    df = df.dropna(axis = 0)
    
    return df
    
def get_Normal_results_set(path = "../data/gru_metaphone"):
    folds = []

    for i in range(5):
        test_csv = os.path.join(trained_folder, f"test_k{i}.csv")
        df = pd.read_csv(test_csv, usecols=["name1", "name2", "label"])
        df = df.astype({"label": bool, "name1": str, "name2": str})
        df = df.rename(columns={"name1": "name0", "name2": "name1", "label": "gt_label"})
        df["gt_label"] = df["gt_label"].astype(int)


        folds.append(df)

    df = pd.concat(folds, axis = 0)
    
    return df

directory = {"1800s_ln": get_1800s_ln_results_set, "1800s_fn": get_1800s_fn_results_set, "Normal": get_Normal_results_set}
function = directory[result_set]
results_set = function()
results_set
# Out:
#            name0       name1  gt_label
# 0        dessell     pessall         0
# 1        ellgood      elwood         0
# 2         ermann       erman         1
# 3         koland     nowland         0
# 4       radebach     rasbach         0
# ...          ...         ...       ...
# 14995      eoute      rankle         0
# 14996     dossin      gossin         0
# 14997       izor  nordenberg         0
# 14998    schnars    schnarrs         1
# 14999  warnement   warnament         1
#
# [75000 rows x 3 columns]

# %% [markdown]
# # 5. Run models on result set
#
# Creates DL classification (score), DL classification (label), and RF classification

# %%
results_dir = results_set.to_dict('records')
results_dir_out = list()

for index, pair in enumerate(results_dir):
    # Deep Learning:
    n1_emb = str2emb(pair['name0']).unsqueeze(0)
    n2_emb = str2emb(pair['name1']).unsqueeze(0)

    score_list = []
    label_list = []

    for model, threshold in zip(dl_models, DL_thrsholds):
        #print(n1_emb, n2_emb)
        score, (_, _) = model(n1_emb, n2_emb)
        score = score.item()
        score_list.append(score)

        label = 1 if score > threshold else 0

        label_list.append(label)

    DL_classification_score = sum(score_list) / 5
    DL_classification_label = 1 if label_list.count(1) >= 3 else 0

    # Random Forest:
    pair_rf_input = {"name_a": pair["name0"], "name_b": pair["name1"], "label": pair["gt_label"]}
    input_df = pd.DataFrame(pair_rf_input, index = [0])
    rf_features = create_RF_features(input_df)
    X_test = rf_features.drop(columns=['name_a', 'name_b', 'label'])

    label_list = []

    for model in rf_models:
        label = model.predict(X_test)
        label_list.append(label)

    RF_classification_label = 1 if label_list.count(True) >= 3 else 0

    out = {"name0": pair['name0'], "name1": pair['name1'], "gt_label": pair['gt_label'], "DL_classification_score": DL_classification_score, \
           "DL_classification_label": DL_classification_label, "RF_classification_label": RF_classification_label}
    results_dir_out.append(out)

    if index % 100 == 0:
        print(index, out)

results_set = pd.DataFrame(results_dir_out)
results_set
# Out:
# 0 {'name0': 'dessell', 'name1': 'pessall', 'gt_label': 0, 'DL_classification_score': 0.4728097140789032, 'DL_classification_label': 0, 'RF_classification_label': 0}
# 100 {'name0': 'uselman', 'name1': 'usselman', 'gt_label': 1, 'DL_classification_score': 0.9599664688110352, 'DL_classification_label': 1, 'RF_classification_label': 1}
# 200 {'name0': 'humphry', 'name1': 'heaslet', 'gt_label': 0, 'DL_classification_score': 0.5513315260410309, 'DL_classification_label': 0, 'RF_classification_label': 0}
# 300 {'name0': 'hetrick', 'name1': 'hetzke', 'gt_label': 0, 'DL_classification_score': 0.5893280982971192, 'DL_classification_label': 0, 'RF_classification_label': 0}
# 400 {'name0': 'schaurer', 'name1': 'scheuren', 'gt_label': 0, 'DL_classification_score': 0.4880423963069916, 'DL_classification_label': 0, 'RF_classification_label': 0}
# 500 {'name0': 'bardson', 'name1': 'maryson', 'gt_label': 0, 'DL_classification_score': 0.43894789218902586, 'DL_classification_label': 0, 'RF_classification_label': 0}
# 600 {'name0': 'dobkowski', 'name1': 'dukowski', 'gt_label': 0, 'DL_classification_score': 0.44483280181884766, 'DL_classification_label': 0, 'RF_classification_label': 0}
# 700 {'name0': 'cottrell', 'name1': 'jaeke', 'gt_label': 0, 'DL_classification_score': 0.47087514996528623, 'DL_classification_label': 0, 'RF_classification_label': 0}
# 800 {'name0': 'caltrider', 'name1': 'hogen', 'gt_label': 0, 'DL_classification_score': 0.5051034450531006, 'DL_classification_label': 0, 'RF_classification_label': 0}
# 900 {'name0': 'quirouette', 'name1': 'freddle', 'gt_label': 0, 'DL_classification_score': 0.4697277843952179, 'DL_classification_label': 0, 'RF_classification_label': 0}
# 1000 {'name0': 'barsen', 'name1': 'bearson', 'gt_label': 0, 'DL_classification_score': 0.7841370105743408, 'DL_classification_label': 0, 'RF_classification_label': 0}
# 1100 {'name0': 'willcocks', 'name1': 'wilcocks', 'gt_label': 1, 'DL_classification_score': 0.9598362445831299, 'DL_classification_label': 1, 'RF_classification_label': 1}
# 1200 {'name0': 'roushar', 'name1': 'rusher', 'gt_label': 0, 'DL_classification_score': 0.6464955568313598, 'DL_classification_label': 0, 'RF_classification_label': 0}
# 1300 {'name0': 'horp', 'name1': 'sumter', 'gt_label': 0, 'DL_classification_score': 0.46304322481155397, 'DL_classification_label': 0, 'RF_classification_label': 0}
# 1400 {'name0': 'whincup', 'name1': 'wincup', 'gt_label': 1, 'DL_classification_score': 0.8991553783416748, 'DL_classification_label': 1, 'RF_classification_label': 1}
# 1500 {'name0': 'gillings', 'name1': 'gellings', 'gt_label': 1, 'DL_classification_score': 0.9487866520881653, 'DL_classification_label': 1, 'RF_classification_label': 1}
# 1600 {'name0': 'shewmaker', 'name1': 'sleymaker', 'gt_label': 0, 'DL_classification_score': 0.5527467668056488, 'DL_classification_label': 0, 'RF_classification_label': 0}
# 1700 {'name0': 'beltran', 'name1': 'bertron', 'gt_label': 0, 'DL_classification_score': 0.4980758845806122, 'DL_classification_label': 0, 'RF_classification_label': 0}
# 1800 {'name0': 'herwick', 'name1': 'perrick', 'gt_label': 0, 'DL_classification_score': 0.44549641013145447, 'DL_classification_label': 0, 'RF_classification_label': 0}
# 1900 {'name0': 'blinkinsop', 'name1': 'freemanmitford', 'gt_label': 0, 'DL_classification_score': 0.5821250319480896, 'DL_classification_label': 0, 'RF_classification_label': 0}
# 2000 {'name0': 'papin', 'name1': 'pupin', 'gt_label': 0, 'DL_classification_score': 0.656166958808899, 'DL_classification_label': 0, 'RF_classification_label': 1}
# 2100 {'name0': 'blwins', 'name1': 'milmoe', 'gt_label': 0, 'DL_classification_score': 0.48094346523284914, 'DL_classification_label': 0, 'RF_classification_label': 0}
# 2200 {'name0': 'strickfather', 'name1': 'cleaver', 'gt_label': 0, 'DL_classification_score': 0.49240574836730955, 'DL_classification_label': 0, 'RF_classification_label': 0}
# 2300 {'name0': 'witcomb', 'name1': 'witcombe', 'gt_label': 1, 'DL_classification_score': 0.9837026476860047, 'DL_classification_label': 1, 'RF_classification_label': 1}
# 2400 {'name0': 'yentsch', 'name1': 'sicco', 'gt_label': 0, 'DL_classification_score': 0.549032324552536, 'DL_classification_label': 0, 'RF_classification_label': 0}
# 2500 {'name0': 'conell', 'name1': 'conerly', 'gt_label': 0, 'DL_classification_score': 0.5345176100730896, 'DL_classification_label': 0, 'RF_classification_label': 0}
# 2600 {'name0': 'bremermann', 'name1': 'bremman', 'gt_label': 0, 'DL_classification_score': 0.6948602795600891, 'DL_classification_label': 0, 'RF_classification_label': 0}
# 2700 {'name0': 'goat', 'name1': 'goate', 'gt_label': 1, 'DL_classification_score': 0.9651851534843445, 'DL_classification_label': 1, 'RF_classification_label': 1}
# 2800 {'name0': 'clendenin', 'name1': 'clendenen', 'gt_label': 1, 'DL_classification_score': 0.9739170908927918, 'DL_classification_label': 1, 'RF_classification_label': 1}
# 2900 {'name0': 'imlay', 'name1': 'imley', 'gt_label': 1, 'DL_classification_score': 0.950783908367157, 'DL_classification_label': 1, 'RF_classification_label': 1}
# 3000 {'name0': 'fetherman', 'name1': 'featherman', 'gt_label': 1, 'DL_classification_score': 0.9179116487503052, 'DL_classification_label': 1, 'RF_classification_label': 1}
# 3100 {'name0': 'sinquefield', 'name1': 'sinkfield', 'gt_label': 1, 'DL_classification_score': 0.8158093929290772, 'DL_classification_label': 1, 'RF_classification_label': 1}
# 3200 {'name0': 'briton', 'name1': 'gruidl', 'gt_label': 0, 'DL_classification_score': 0.40326922535896303, 'DL_classification_label': 0, 'RF_classification_label': 0}
# 3300 {'name0': 'saleman', 'name1': 'salsman', 'gt_label': 0, 'DL_classification_score': 0.7534937024116516, 'DL_classification_label': 0, 'RF_classification_label': 0}
# 3400 {'name0': 'murcott', 'name1': 'muscott', 'gt_label': 1, 'DL_classification_score': 0.7103741884231567, 'DL_classification_label': 0, 'RF_classification_label': 0}
# 3500 {'name0': 'serventi', 'name1': 'taman', 'gt_label': 0, 'DL_classification_score': 0.5131017506122589, 'DL_classification_label': 0, 'RF_classification_label': 0}
# 3600 {'name0': 'mcelvany', 'name1': 'mcelvaney', 'gt_label': 1, 'DL_classification_score': 0.983955466747284, 'DL_classification_label': 1, 'RF_classification_label': 1}
# 3700 {'name0': 'heppleston', 'name1': 'hepplestone', 'gt_label': 1, 'DL_classification_score': 0.9880960583686829, 'DL_classification_label': 1, 'RF_classification_label': 1}
# 3800 {'name0': 'selix', 'name1': 'doepke', 'gt_label': 0, 'DL_classification_score': 0.5249992311000824, 'DL_classification_label': 0, 'RF_classification_label': 0}
# 3900 {'name0': 'farrimond', 'name1': 'spigler', 'gt_label': 0, 'DL_classification_score': 0.4849180817604065, 'DL_classification_label': 0, 'RF_classification_label': 0}
# 4000 {'name0': 'motten', 'name1': 'motton', 'gt_label': 0, 'DL_classification_score': 0.8798884153366089, 'DL_classification_label': 1, 'RF_classification_label': 1}
# 4100 {'name0': 'kessell', 'name1': 'kussel', 'gt_label': 0, 'DL_classification_score': 0.6720186948776246, 'DL_classification_label': 0, 'RF_classification_label': 0}
# 4200 {'name0': 'bettesworth', 'name1': 'bettsworth', 'gt_label': 1, 'DL_classification_score': 0.9635635256767273, 'DL_classification_label': 1, 'RF_classification_label': 1}
# 4300 {'name0': 'hesher', 'name1': 'rhodts', 'gt_label': 0, 'DL_classification_score': 0.46371219158172605, 'DL_classification_label': 0, 'RF_classification_label': 0}
# 4400 {'name0': 'morpeth', 'name1': 'marpeth', 'gt_label': 1, 'DL_classification_score': 0.9020866394042969, 'DL_classification_label': 1, 'RF_classification_label': 1}
# 4500 {'name0': 'fitzalan', 'name1': 'goushill', 'gt_label': 1, 'DL_classification_score': 0.5490100383758545, 'DL_classification_label': 0, 'RF_classification_label': 1}
# 4600 {'name0': 'hannert', 'name1': 'shanner', 'gt_label': 0, 'DL_classification_score': 0.5944557547569275, 'DL_classification_label': 0, 'RF_classification_label': 0}
# 4700 {'name0': 'desomer', 'name1': 'domer', 'gt_label': 0, 'DL_classification_score': 0.5956743955612183, 'DL_classification_label': 0, 'RF_classification_label': 0}
# 4800 {'name0': 'charo', 'name1': 'chara', 'gt_label': 1, 'DL_classification_score': 0.8881204962730408, 'DL_classification_label': 1, 'RF_classification_label': 1}
# 4900 {'name0': 'draughon', 'name1': 'draughan', 'gt_label': 1, 'DL_classification_score': 0.9752143144607544, 'DL_classification_label': 1, 'RF_classification_label': 1}
# 5000 {'name0': 'siemsen', 'name1': 'gravenhorst', 'gt_label': 0, 'DL_classification_score': 0.48481252789497375, 'DL_classification_label': 0, 'RF_classification_label': 0}
# 5100 {'name0': 'morper', 'name1': 'donalan', 'gt_label': 0, 'DL_classification_score': 0.5316181600093841, 'DL_classification_label': 0, 'RF_classification_label': 0}
# 5200 {'name0': 'bodenstiner', 'name1': 'rosenstine', 'gt_label': 0, 'DL_classification_score': 0.47456197142601014, 'DL_classification_label': 0, 'RF_classification_label': 0}
# 5300 {'name0': 'naes', 'name1': 'shaws', 'gt_label': 0, 'DL_classification_score': 0.5924167335033417, 'DL_classification_label': 0, 'RF_classification_label': 0}
# 5400 {'name0': 'arthurhultz', 'name1': 'arthurhults', 'gt_label': 1, 'DL_classification_score': 0.9875868201255799, 'DL_classification_label': 1, 'RF_classification_label': 1}
# 5500 {'name0': 'treichel', 'name1': 'lufriu', 'gt_label': 0, 'DL_classification_score': 0.4749671876430511, 'DL_classification_label': 0, 'RF_classification_label': 0}
# 5600 {'name0': 'dearden', 'name1': 'dearon', 'gt_label': 0, 'DL_classification_score': 0.49992985725402833, 'DL_classification_label': 0, 'RF_classification_label': 0}
# 5700 {'name0': 'kinery', 'name1': 'klinert', 'gt_label': 0, 'DL_classification_score': 0.5327714204788208, 'DL_classification_label': 0, 'RF_classification_label': 0}
# 5800 {'name0': 'bost', 'name1': 'mckilroy', 'gt_label': 0, 'DL_classification_score': 0.565670520067215, 'DL_classification_label': 0, 'RF_classification_label': 0}
# 5900 {'name0': 'phalon', 'name1': 'philon', 'gt_label': 0, 'DL_classification_score': 0.72141432762146, 'DL_classification_label': 0, 'RF_classification_label': 1}
# 6000 {'name0': 'coply', 'name1': 'gronemeier', 'gt_label': 0, 'DL_classification_score': 0.4476403295993805, 'DL_classification_label': 0, 'RF_classification_label': 0}
# 6100 {'name0': 'rofidal', 'name1': 'roibal', 'gt_label': 0, 'DL_classification_score': 0.6235491514205933, 'DL_classification_label': 0, 'RF_classification_label': 0}
# 6200 {'name0': 'chandon', 'name1': 'hanion', 'gt_label': 0, 'DL_classification_score': 0.5572327196598053, 'DL_classification_label': 0, 'RF_classification_label': 0}
# 6300 {'name0': 'pitsenberger', 'name1': 'spitzenberger', 'gt_label': 0, 'DL_classification_score': 0.5741427600383758, 'DL_classification_label': 0, 'RF_classification_label': 0}
# 6400 {'name0': 'bette', 'name1': 'betto', 'gt_label': 0, 'DL_classification_score': 0.8653706312179565, 'DL_classification_label': 1, 'RF_classification_label': 1}
# 6500 {'name0': 'hugdahl', 'name1': 'brungess', 'gt_label': 0, 'DL_classification_score': 0.5096146643161774, 'DL_classification_label': 0, 'RF_classification_label': 0}
# 6600 {'name0': 'millican', 'name1': 'milican', 'gt_label': 1, 'DL_classification_score': 0.9107671260833741, 'DL_classification_label': 1, 'RF_classification_label': 1}
# 6700 {'name0': 'bleoins', 'name1': 'brewins', 'gt_label': 0, 'DL_classification_score': 0.4940744400024414, 'DL_classification_label': 0, 'RF_classification_label': 0}
# 6800 {'name0': 'spitzner', 'name1': 'oldom', 'gt_label': 0, 'DL_classification_score': 0.5208639025688171, 'DL_classification_label': 0, 'RF_classification_label': 0}
# 6900 {'name0': 'hembury', 'name1': 'hembry', 'gt_label': 1, 'DL_classification_score': 0.8779317975044251, 'DL_classification_label': 1, 'RF_classification_label': 1}
# 7000 {'name0': 'callicoat', 'name1': 'calicoat', 'gt_label': 1, 'DL_classification_score': 0.9618951916694641, 'DL_classification_label': 1, 'RF_classification_label': 1}
# 7100 {'name0': 'niebel', 'name1': 'neibel', 'gt_label': 1, 'DL_classification_score': 0.9808305263519287, 'DL_classification_label': 1, 'RF_classification_label': 1}
# 7200 {'name0': 'fessey', 'name1': 'fossey', 'gt_label': 0, 'DL_classification_score': 0.7401715993881226, 'DL_classification_label': 0, 'RF_classification_label': 1}
# 7300 {'name0': 'bixenmann', 'name1': 'bixeman', 'gt_label': 1, 'DL_classification_score': 0.9004077553749085, 'DL_classification_label': 1, 'RF_classification_label': 1}
# 7400 {'name0': 'beecken', 'name1': 'hecken', 'gt_label': 0, 'DL_classification_score': 0.459694641828537, 'DL_classification_label': 0, 'RF_classification_label': 0}
# 7500 {'name0': 'zable', 'name1': 'pettit', 'gt_label': 0, 'DL_classification_score': 0.5026376247406006, 'DL_classification_label': 0, 'RF_classification_label': 0}
# 7600 {'name0': 'daniels', 'name1': 'daniel', 'gt_label': 1, 'DL_classification_score': 0.8768920779228211, 'DL_classification_label': 1, 'RF_classification_label': 1}
# 7700 {'name0': 'pittelko', 'name1': 'pittelkow', 'gt_label': 1, 'DL_classification_score': 0.8836223840713501, 'DL_classification_label': 1, 'RF_classification_label': 1}
# 7800 {'name0': 'bassingthwaighte', 'name1': 'bassingthwaite', 'gt_label': 1, 'DL_classification_score': 0.9620576143264771, 'DL_classification_label': 1, 'RF_classification_label': 1}
# 7900 {'name0': 'aldam', 'name1': 'aldan', 'gt_label': 1, 'DL_classification_score': 0.8395086407661438, 'DL_classification_label': 1, 'RF_classification_label': 1}
# 8000 {'name0': 'soncrant', 'name1': 'harniman', 'gt_label': 0, 'DL_classification_score': 0.4602779924869537, 'DL_classification_label': 0, 'RF_classification_label': 0}
# 8100 {'name0': 'troglen', 'name1': 'troxler', 'gt_label': 0, 'DL_classification_score': 0.6327026605606079, 'DL_classification_label': 0, 'RF_classification_label': 0}
# 8200 {'name0': 'summie', 'name1': 'transier', 'gt_label': 0, 'DL_classification_score': 0.5146459221839905, 'DL_classification_label': 0, 'RF_classification_label': 0}
# 8300 {'name0': 'hedgman', 'name1': 'hedgeman', 'gt_label': 1, 'DL_classification_score': 0.7280431985855103, 'DL_classification_label': 0, 'RF_classification_label': 1}
# 8400 {'name0': 'score', 'name1': 'noseley', 'gt_label': 0, 'DL_classification_score': 0.458245176076889, 'DL_classification_label': 0, 'RF_classification_label': 0}
# 8500 {'name0': 'girsch', 'name1': 'liffler', 'gt_label': 0, 'DL_classification_score': 0.5178207278251648, 'DL_classification_label': 0, 'RF_classification_label': 0}
# 8600 {'name0': 'rockefeller', 'name1': 'rockafeller', 'gt_label': 1, 'DL_classification_score': 0.9711966037750244, 'DL_classification_label': 1, 'RF_classification_label': 1}
# 8700 {'name0': 'malabar', 'name1': 'malaby', 'gt_label': 0, 'DL_classification_score': 0.6675160646438598, 'DL_classification_label': 0, 'RF_classification_label': 0}
# 8800 {'name0': 'kilgannon', 'name1': 'kilganon', 'gt_label': 1, 'DL_classification_score': 0.9653706550598145, 'DL_classification_label': 1, 'RF_classification_label': 1}
# 8900 {'name0': 'groening', 'name1': 'groezinger', 'gt_label': 0, 'DL_classification_score': 0.6284745872020722, 'DL_classification_label': 0, 'RF_classification_label': 0}
# 9000 {'name0': 'chatterley', 'name1': 'barnar', 'gt_label': 0, 'DL_classification_score': 0.5857165396213532, 'DL_classification_label': 0, 'RF_classification_label': 0}
# 9100 {'name0': 'cymru', 'name1': 'castells', 'gt_label': 0, 'DL_classification_score': 0.5315082669258118, 'DL_classification_label': 0, 'RF_classification_label': 0}
# 9200 {'name0': 'fieselmann', 'name1': 'fieselman', 'gt_label': 1, 'DL_classification_score': 0.9829290866851806, 'DL_classification_label': 1, 'RF_classification_label': 1}
# 9300 {'name0': 'jaen', 'name1': 'waddlow', 'gt_label': 0, 'DL_classification_score': 0.42831509113311766, 'DL_classification_label': 0, 'RF_classification_label': 0}
# 9400 {'name0': 'gettemeier', 'name1': 'gittemeier', 'gt_label': 1, 'DL_classification_score': 0.9311824560165405, 'DL_classification_label': 1, 'RF_classification_label': 1}
# 9500 {'name0': 'berrel', 'name1': 'serrels', 'gt_label': 0, 'DL_classification_score': 0.47643818855285647, 'DL_classification_label': 0, 'RF_classification_label': 0}
# 9600 {'name0': 'tremaine', 'name1': 'schnurman', 'gt_label': 0, 'DL_classification_score': 0.5371490001678467, 'DL_classification_label': 0, 'RF_classification_label': 0}
# 9700 {'name0': 'palgrave', 'name1': 'beightol', 'gt_label': 0, 'DL_classification_score': 0.5795171141624451, 'DL_classification_label': 0, 'RF_classification_label': 0}
# 9800 {'name0': 'hardenberg', 'name1': 'dutartre', 'gt_label': 0, 'DL_classification_score': 0.48515431880950927, 'DL_classification_label': 0, 'RF_classification_label': 0}
# 9900 {'name0': 'etherage', 'name1': 'keenahan', 'gt_label': 0, 'DL_classification_score': 0.5185561418533325, 'DL_classification_label': 0, 'RF_classification_label': 0}
# 10000 {'name0': 'biedermann', 'name1': 'revermann', 'gt_label': 0, 'DL_classification_score': 0.4400780022144318, 'DL_classification_label': 0, 'RF_classification_label': 0}
# 10100 {'name0': 'wigness', 'name1': 'holway', 'gt_label': 0, 'DL_classification_score': 0.42742201685905457, 'DL_classification_label': 0, 'RF_classification_label': 0}
# 10200 {'name0': 'hotsenpillar', 'name1': 'piersey', 'gt_label': 0, 'DL_classification_score': 0.5714124441146851, 'DL_classification_label': 0, 'RF_classification_label': 0}
# 10300 {'name0': 'tharrington', 'name1': 'remers', 'gt_label': 0, 'DL_classification_score': 0.5320972681045533, 'DL_classification_label': 0, 'RF_classification_label': 0}
# 10400 {'name0': 'fiedler', 'name1': 'feidler', 'gt_label': 1, 'DL_classification_score': 0.992239236831665, 'DL_classification_label': 1, 'RF_classification_label': 1}
# 10500 {'name0': 'faison', 'name1': 'marison', 'gt_label': 0, 'DL_classification_score': 0.5146885395050049, 'DL_classification_label': 0, 'RF_classification_label': 0}
# 10600 {'name0': 'buckfield', 'name1': 'tuveson', 'gt_label': 0, 'DL_classification_score': 0.5444038033485412, 'DL_classification_label': 0, 'RF_classification_label': 0}
# 10700 {'name0': 'oakry', 'name1': 'sterba', 'gt_label': 0, 'DL_classification_score': 0.5047614991664886, 'DL_classification_label': 0, 'RF_classification_label': 0}
# 10800 {'name0': 'wedgbury', 'name1': 'wedgebury', 'gt_label': 1, 'DL_classification_score': 0.7934158563613891, 'DL_classification_label': 0, 'RF_classification_label': 1}
# 10900 {'name0': 'candlin', 'name1': 'candling', 'gt_label': 1, 'DL_classification_score': 0.7811610579490662, 'DL_classification_label': 0, 'RF_classification_label': 1}
# 11000 {'name0': 'mercereau', 'name1': 'mersereau', 'gt_label': 1, 'DL_classification_score': 0.8981284737586975, 'DL_classification_label': 1, 'RF_classification_label': 1}
# 11100 {'name0': 'cossler', 'name1': 'dissler', 'gt_label': 0, 'DL_classification_score': 0.5186506152153015, 'DL_classification_label': 0, 'RF_classification_label': 0}
# 11200 {'name0': 'geates', 'name1': 'boserman', 'gt_label': 0, 'DL_classification_score': 0.4469581961631775, 'DL_classification_label': 0, 'RF_classification_label': 0}
# 11300 {'name0': 'rocko', 'name1': 'battenhausen', 'gt_label': 0, 'DL_classification_score': 0.5385828793048859, 'DL_classification_label': 0, 'RF_classification_label': 0}
# 11400 {'name0': 'shumpert', 'name1': 'schumpert', 'gt_label': 1, 'DL_classification_score': 0.9311949372291565, 'DL_classification_label': 1, 'RF_classification_label': 1}
# 11500 {'name0': 'vanderwaal', 'name1': 'vernom', 'gt_label': 0, 'DL_classification_score': 0.5118154287338257, 'DL_classification_label': 0, 'RF_classification_label': 0}
# 11600 {'name0': 'ploetz', 'name1': 'plotz', 'gt_label': 1, 'DL_classification_score': 0.9413280367851258, 'DL_classification_label': 1, 'RF_classification_label': 1}
# 11700 {'name0': 'feamster', 'name1': 'tennington', 'gt_label': 0, 'DL_classification_score': 0.5887787222862244, 'DL_classification_label': 0, 'RF_classification_label': 0}
# 11800 {'name0': 'carkin', 'name1': 'mcclease', 'gt_label': 0, 'DL_classification_score': 0.6124975264072419, 'DL_classification_label': 0, 'RF_classification_label': 0}
# 11900 {'name0': 'hoodenpyl', 'name1': 'hoodenpyle', 'gt_label': 1, 'DL_classification_score': 0.9922228813171386, 'DL_classification_label': 1, 'RF_classification_label': 1}
# 12000 {'name0': 'crooker', 'name1': 'lony', 'gt_label': 0, 'DL_classification_score': 0.5235705554485321, 'DL_classification_label': 0, 'RF_classification_label': 0}
# 12100 {'name0': 'coldren', 'name1': 'wolden', 'gt_label': 0, 'DL_classification_score': 0.5202396512031555, 'DL_classification_label': 0, 'RF_classification_label': 0}
# 12200 {'name0': 'sheller', 'name1': 'shipler', 'gt_label': 0, 'DL_classification_score': 0.4888797402381897, 'DL_classification_label': 0, 'RF_classification_label': 0}
# 12300 {'name0': 'liebtag', 'name1': 'leibtag', 'gt_label': 1, 'DL_classification_score': 0.993426525592804, 'DL_classification_label': 1, 'RF_classification_label': 1}
# 12400 {'name0': 'dechristopher', 'name1': 'bettany', 'gt_label': 0, 'DL_classification_score': 0.4976722657680511, 'DL_classification_label': 0, 'RF_classification_label': 0}
# 12500 {'name0': 'abnett', 'name1': 'arnnett', 'gt_label': 0, 'DL_classification_score': 0.5700481057167053, 'DL_classification_label': 0, 'RF_classification_label': 0}
# 12600 {'name0': 'windmeyer', 'name1': 'wismeyer', 'gt_label': 0, 'DL_classification_score': 0.5452652990818023, 'DL_classification_label': 0, 'RF_classification_label': 0}
# 12700 {'name0': 'dreany', 'name1': 'draney', 'gt_label': 1, 'DL_classification_score': 0.9139100313186646, 'DL_classification_label': 1, 'RF_classification_label': 1}
# 12800 {'name0': 'hight', 'name1': 'hoight', 'gt_label': 0, 'DL_classification_score': 0.6771113991737365, 'DL_classification_label': 0, 'RF_classification_label': 0}
# 12900 {'name0': 'lemaine', 'name1': 'tomaine', 'gt_label': 0, 'DL_classification_score': 0.4583103656768799, 'DL_classification_label': 0, 'RF_classification_label': 0}
# 13000 {'name0': 'longdo', 'name1': 'portrey', 'gt_label': 0, 'DL_classification_score': 0.579961508512497, 'DL_classification_label': 0, 'RF_classification_label': 0}
# 13100 {'name0': 'geldermann', 'name1': 'gelderman', 'gt_label': 1, 'DL_classification_score': 0.9887159824371338, 'DL_classification_label': 1, 'RF_classification_label': 1}
# 13200 {'name0': 'tasto', 'name1': 'tasta', 'gt_label': 1, 'DL_classification_score': 0.9706106305122375, 'DL_classification_label': 1, 'RF_classification_label': 1}
# 13300 {'name0': 'mccosker', 'name1': 'habbot', 'gt_label': 0, 'DL_classification_score': 0.5914033412933349, 'DL_classification_label': 0, 'RF_classification_label': 0}
# 13400 {'name0': 'hainlen', 'name1': 'hartlen', 'gt_label': 0, 'DL_classification_score': 0.5387435913085937, 'DL_classification_label': 0, 'RF_classification_label': 0}
# 13500 {'name0': 'marstiller', 'name1': 'marsteller', 'gt_label': 1, 'DL_classification_score': 0.965122401714325, 'DL_classification_label': 1, 'RF_classification_label': 1}
# 13600 {'name0': 'ledgway', 'name1': 'fabeck', 'gt_label': 0, 'DL_classification_score': 0.4846765697002411, 'DL_classification_label': 0, 'RF_classification_label': 0}
# 13700 {'name0': 'hergenreder', 'name1': 'kuikendall', 'gt_label': 0, 'DL_classification_score': 0.4987423658370972, 'DL_classification_label': 0, 'RF_classification_label': 0}
# 13800 {'name0': 'woodland', 'name1': 'wooland', 'gt_label': 0, 'DL_classification_score': 0.6831845164299011, 'DL_classification_label': 0, 'RF_classification_label': 0}
# 13900 {'name0': 'galles', 'name1': 'qualles', 'gt_label': 0, 'DL_classification_score': 0.6762270331382751, 'DL_classification_label': 0, 'RF_classification_label': 0}
# 14000 {'name0': 'bueghly', 'name1': 'hughly', 'gt_label': 0, 'DL_classification_score': 0.46712281703948977, 'DL_classification_label': 0, 'RF_classification_label': 0}
# 14100 {'name0': 'itz', 'name1': 'whiskard', 'gt_label': 0, 'DL_classification_score': 0.5872461438179016, 'DL_classification_label': 0, 'RF_classification_label': 0}
# 14200 {'name0': 'charping', 'name1': 'sharping', 'gt_label': 1, 'DL_classification_score': 0.7132619738578796, 'DL_classification_label': 0, 'RF_classification_label': 1}
# 14300 {'name0': 'cornman', 'name1': 'orman', 'gt_label': 0, 'DL_classification_score': 0.5460915446281434, 'DL_classification_label': 0, 'RF_classification_label': 0}
# 14400 {'name0': 'pummell', 'name1': 'pummel', 'gt_label': 1, 'DL_classification_score': 0.95204598903656, 'DL_classification_label': 1, 'RF_classification_label': 1}
# 14500 {'name0': 'bossingham', 'name1': 'bringham', 'gt_label': 0, 'DL_classification_score': 0.5701521873474121, 'DL_classification_label': 0, 'RF_classification_label': 0}
# 14600 {'name0': 'barricks', 'name1': 'barracks', 'gt_label': 1, 'DL_classification_score': 0.8731099843978882, 'DL_classification_label': 1, 'RF_classification_label': 1}
# 14700 {'name0': 'denley', 'name1': 'denly', 'gt_label': 1, 'DL_classification_score': 0.9740320205688476, 'DL_classification_label': 1, 'RF_classification_label': 1}
# 14800 {'name0': 'santimore', 'name1': 'santmyre', 'gt_label': 0, 'DL_classification_score': 0.9137677311897278, 'DL_classification_label': 1, 'RF_classification_label': 1}
# 14900 {'name0': 'schofeld', 'name1': 'reints', 'gt_label': 0, 'DL_classification_score': 0.5466343641281128, 'DL_classification_label': 0, 'RF_classification_label': 0}
# 15000 {'name0': 'bieske', 'name1': 'breske', 'gt_label': 0, 'DL_classification_score': 0.5818443059921264, 'DL_classification_label': 0, 'RF_classification_label': 1}
# 15100 {'name0': 'eudaly', 'name1': 'eudaley', 'gt_label': 1, 'DL_classification_score': 0.9805828332901001, 'DL_classification_label': 1, 'RF_classification_label': 1}
# 15200 {'name0': 'destro', 'name1': 'usmer', 'gt_label': 0, 'DL_classification_score': 0.4736616790294647, 'DL_classification_label': 0, 'RF_classification_label': 0}
# 15300 {'name0': 'erlbacher', 'name1': 'husslebee', 'gt_label': 0, 'DL_classification_score': 0.4651624083518982, 'DL_classification_label': 0, 'RF_classification_label': 0}
# 15400 {'name0': 'bandler', 'name1': 'fander', 'gt_label': 0, 'DL_classification_score': 0.6121088266372681, 'DL_classification_label': 0, 'RF_classification_label': 0}
# 15500 {'name0': 'mceleheney', 'name1': 'mcelhaney', 'gt_label': 0, 'DL_classification_score': 0.7997288703918457, 'DL_classification_label': 1, 'RF_classification_label': 0}
# 15600 {'name0': 'siekman', 'name1': 'sleaman', 'gt_label': 0, 'DL_classification_score': 0.5509241402149201, 'DL_classification_label': 0, 'RF_classification_label': 0}
# 15700 {'name0': 'nichalls', 'name1': 'kieland', 'gt_label': 0, 'DL_classification_score': 0.443136590719223, 'DL_classification_label': 0, 'RF_classification_label': 0}
# 15800 {'name0': 'mosberg', 'name1': 'dahlinger', 'gt_label': 0, 'DL_classification_score': 0.5186351835727692, 'DL_classification_label': 0, 'RF_classification_label': 0}
# 15900 {'name0': 'gunthert', 'name1': 'myton', 'gt_label': 0, 'DL_classification_score': 0.4609601616859436, 'DL_classification_label': 0, 'RF_classification_label': 0}
# 16000 {'name0': 'mandl', 'name1': 'mandley', 'gt_label': 0, 'DL_classification_score': 0.7075186967849731, 'DL_classification_label': 0, 'RF_classification_label': 1}
# 16100 {'name0': 'beedie', 'name1': 'beddie', 'gt_label': 1, 'DL_classification_score': 0.8697153449058532, 'DL_classification_label': 1, 'RF_classification_label': 1}
# 16200 {'name0': 'haysley', 'name1': 'horsley', 'gt_label': 0, 'DL_classification_score': 0.633948928117752, 'DL_classification_label': 0, 'RF_classification_label': 0}
# 16300 {'name0': 'blundred', 'name1': 'eltham', 'gt_label': 0, 'DL_classification_score': 0.507667750120163, 'DL_classification_label': 0, 'RF_classification_label': 0}
# 16400 {'name0': 'coathup', 'name1': 'coatup', 'gt_label': 1, 'DL_classification_score': 0.6514545559883118, 'DL_classification_label': 0, 'RF_classification_label': 1}
# 16500 {'name0': 'adlam', 'name1': 'adlem', 'gt_label': 1, 'DL_classification_score': 0.949565839767456, 'DL_classification_label': 1, 'RF_classification_label': 1}
# 16600 {'name0': 'baughton', 'name1': 'laighton', 'gt_label': 0, 'DL_classification_score': 0.4816979467868805, 'DL_classification_label': 0, 'RF_classification_label': 0}
# 16700 {'name0': 'friedler', 'name1': 'siedler', 'gt_label': 0, 'DL_classification_score': 0.47618855237960817, 'DL_classification_label': 0, 'RF_classification_label': 0}
# 16800 {'name0': 'gillon', 'name1': 'millon', 'gt_label': 0, 'DL_classification_score': 0.5473261594772338, 'DL_classification_label': 0, 'RF_classification_label': 0}
# 16900 {'name0': 'goettler', 'name1': 'bruget', 'gt_label': 0, 'DL_classification_score': 0.5055879890918732, 'DL_classification_label': 0, 'RF_classification_label': 0}
# 17000 {'name0': 'gosland', 'name1': 'woxland', 'gt_label': 0, 'DL_classification_score': 0.5681495428085327, 'DL_classification_label': 0, 'RF_classification_label': 0}
# 17100 {'name0': 'banchero', 'name1': 'medly', 'gt_label': 0, 'DL_classification_score': 0.5562750637531281, 'DL_classification_label': 0, 'RF_classification_label': 0}
# 17200 {'name0': 'garau', 'name1': 'stooks', 'gt_label': 0, 'DL_classification_score': 0.4422184944152832, 'DL_classification_label': 0, 'RF_classification_label': 0}
# 17300 {'name0': 'forgues', 'name1': 'forgue', 'gt_label': 1, 'DL_classification_score': 0.9004796028137207, 'DL_classification_label': 1, 'RF_classification_label': 1}
# 17400 {'name0': 'maylem', 'name1': 'eashe', 'gt_label': 0, 'DL_classification_score': 0.43116753697395327, 'DL_classification_label': 0, 'RF_classification_label': 0}
# 17500 {'name0': 'gholz', 'name1': 'golz', 'gt_label': 0, 'DL_classification_score': 0.8782361268997192, 'DL_classification_label': 1, 'RF_classification_label': 1}
# 17600 {'name0': 'haliman', 'name1': 'hillman', 'gt_label': 0, 'DL_classification_score': 0.6103070318698883, 'DL_classification_label': 0, 'RF_classification_label': 0}
# 17700 {'name0': 'mausbach', 'name1': 'mausback', 'gt_label': 1, 'DL_classification_score': 0.9912356376647949, 'DL_classification_label': 1, 'RF_classification_label': 1}
# 17800 {'name0': 'leuthen', 'name1': 'loethen', 'gt_label': 1, 'DL_classification_score': 0.6926918864250183, 'DL_classification_label': 0, 'RF_classification_label': 0}
# 17900 {'name0': 'kelsheimer', 'name1': 'kelshimer', 'gt_label': 1, 'DL_classification_score': 0.8263759613037109, 'DL_classification_label': 1, 'RF_classification_label': 1}
# 18000 {'name0': 'strassman', 'name1': 'strassmann', 'gt_label': 1, 'DL_classification_score': 0.9924071073532105, 'DL_classification_label': 1, 'RF_classification_label': 1}
# 18100 {'name0': 'hinthorne', 'name1': 'hinthorn', 'gt_label': 1, 'DL_classification_score': 0.9791992902755737, 'DL_classification_label': 1, 'RF_classification_label': 1}
# 18200 {'name0': 'wintworth', 'name1': 'susalla', 'gt_label': 0, 'DL_classification_score': 0.5286538004875183, 'DL_classification_label': 0, 'RF_classification_label': 0}
# 18300 {'name0': 'schepper', 'name1': 'shepper', 'gt_label': 0, 'DL_classification_score': 0.8277158379554749, 'DL_classification_label': 1, 'RF_classification_label': 1}
# 18400 {'name0': 'rautenbusch', 'name1': 'rautenbush', 'gt_label': 1, 'DL_classification_score': 0.982423460483551, 'DL_classification_label': 1, 'RF_classification_label': 1}
# 18500 {'name0': 'barklay', 'name1': 'petersdorf', 'gt_label': 0, 'DL_classification_score': 0.4885930955410004, 'DL_classification_label': 0, 'RF_classification_label': 0}
# 18600 {'name0': 'weisler', 'name1': 'wiesler', 'gt_label': 1, 'DL_classification_score': 0.6748250603675843, 'DL_classification_label': 0, 'RF_classification_label': 1}
# 18700 {'name0': 'omernik', 'name1': 'omernick', 'gt_label': 1, 'DL_classification_score': 0.9702893376350403, 'DL_classification_label': 1, 'RF_classification_label': 1}
# 18800 {'name0': 'fenwick', 'name1': 'erts', 'gt_label': 0, 'DL_classification_score': 0.5144495606422425, 'DL_classification_label': 0, 'RF_classification_label': 0}
# 18900 {'name0': 'ahlswede', 'name1': 'mccarrin', 'gt_label': 0, 'DL_classification_score': 0.5201166868209839, 'DL_classification_label': 0, 'RF_classification_label': 0}
# 19000 {'name0': 'pavick', 'name1': 'pavlock', 'gt_label': 0, 'DL_classification_score': 0.6077451944351197, 'DL_classification_label': 0, 'RF_classification_label': 0}
# 19100 {'name0': 'garrens', 'name1': 'parren', 'gt_label': 0, 'DL_classification_score': 0.4602507412433624, 'DL_classification_label': 0, 'RF_classification_label': 0}
# 19200 {'name0': 'seelbach', 'name1': 'sealbach', 'gt_label': 1, 'DL_classification_score': 0.9359318375587463, 'DL_classification_label': 1, 'RF_classification_label': 1}
# 19300 {'name0': 'rispin', 'name1': 'hidderley', 'gt_label': 0, 'DL_classification_score': 0.44959586262702944, 'DL_classification_label': 0, 'RF_classification_label': 0}
# 19400 {'name0': 'toynton', 'name1': 'tointon', 'gt_label': 1, 'DL_classification_score': 0.9518673181533813, 'DL_classification_label': 1, 'RF_classification_label': 1}
# 19500 {'name0': 'geisinger', 'name1': 'geissinger', 'gt_label': 1, 'DL_classification_score': 0.9674550890922546, 'DL_classification_label': 1, 'RF_classification_label': 1}
# 19600 {'name0': 'bierd', 'name1': 'bird', 'gt_label': 0, 'DL_classification_score': 0.8453516840934754, 'DL_classification_label': 1, 'RF_classification_label': 0}
# 19700 {'name0': 'fender', 'name1': 'swender', 'gt_label': 0, 'DL_classification_score': 0.5034403681755066, 'DL_classification_label': 0, 'RF_classification_label': 0}
# 19800 {'name0': 'lescalleet', 'name1': 'lescallett', 'gt_label': 1, 'DL_classification_score': 0.9779742598533631, 'DL_classification_label': 1, 'RF_classification_label': 1}
# 19900 {'name0': 'kittrell', 'name1': 'kitrell', 'gt_label': 1, 'DL_classification_score': 0.9411944150924683, 'DL_classification_label': 1, 'RF_classification_label': 1}
# 20000 {'name0': 'northcotte', 'name1': 'stimers', 'gt_label': 0, 'DL_classification_score': 0.5128183186054229, 'DL_classification_label': 0, 'RF_classification_label': 0}
# 20100 {'name0': 'broucher', 'name1': 'friskin', 'gt_label': 0, 'DL_classification_score': 0.4621239423751831, 'DL_classification_label': 0, 'RF_classification_label': 0}
# 20200 {'name0': 'serace', 'name1': 'servage', 'gt_label': 0, 'DL_classification_score': 0.4509119987487793, 'DL_classification_label': 0, 'RF_classification_label': 0}
# 20300 {'name0': 'lepert', 'name1': 'puschinsky', 'gt_label': 0, 'DL_classification_score': 0.5609564781188965, 'DL_classification_label': 0, 'RF_classification_label': 0}
# 20400 {'name0': 'lavelle', 'name1': 'lavell', 'gt_label': 1, 'DL_classification_score': 0.9615660309791565, 'DL_classification_label': 1, 'RF_classification_label': 1}
# 20500 {'name0': 'mccambly', 'name1': 'biermann', 'gt_label': 0, 'DL_classification_score': 0.5566467940807343, 'DL_classification_label': 0, 'RF_classification_label': 0}
# 20600 {'name0': 'kicken', 'name1': 'ricken', 'gt_label': 0, 'DL_classification_score': 0.3973234832286835, 'DL_classification_label': 0, 'RF_classification_label': 0}
# 20700 {'name0': 'ademson', 'name1': 'jemson', 'gt_label': 0, 'DL_classification_score': 0.4370171010494232, 'DL_classification_label': 0, 'RF_classification_label': 0}
# 20800 {'name0': 'axsom', 'name1': 'challicom', 'gt_label': 0, 'DL_classification_score': 0.5049968957901001, 'DL_classification_label': 0, 'RF_classification_label': 0}
# 20900 {'name0': 'ricks', 'name1': 'rickson', 'gt_label': 0, 'DL_classification_score': 0.556359612941742, 'DL_classification_label': 0, 'RF_classification_label': 0}
# 21000 {'name0': 'huttenlocker', 'name1': 'trewhela', 'gt_label': 0, 'DL_classification_score': 0.5181219398975372, 'DL_classification_label': 0, 'RF_classification_label': 0}
# 21100 {'name0': 'jipping', 'name1': 'tippings', 'gt_label': 0, 'DL_classification_score': 0.530302780866623, 'DL_classification_label': 0, 'RF_classification_label': 0}
# 21200 {'name0': 'dando', 'name1': 'durando', 'gt_label': 0, 'DL_classification_score': 0.5771627128124237, 'DL_classification_label': 0, 'RF_classification_label': 0}
# 21300 {'name0': 'walkem', 'name1': 'walklet', 'gt_label': 0, 'DL_classification_score': 0.4894648909568787, 'DL_classification_label': 0, 'RF_classification_label': 0}
# 21400 {'name0': 'booroff', 'name1': 'woodroff', 'gt_label': 0, 'DL_classification_score': 0.5035533845424652, 'DL_classification_label': 0, 'RF_classification_label': 0}
# 21500 {'name0': 'dacosta', 'name1': 'menegay', 'gt_label': 0, 'DL_classification_score': 0.5024283766746521, 'DL_classification_label': 0, 'RF_classification_label': 0}
# 21600 {'name0': 'stebbings', 'name1': 'stebbing', 'gt_label': 1, 'DL_classification_score': 0.9566016077995301, 'DL_classification_label': 1, 'RF_classification_label': 1}
# 21700 {'name0': 'roeland', 'name1': 'rouland', 'gt_label': 0, 'DL_classification_score': 0.7165894865989685, 'DL_classification_label': 0, 'RF_classification_label': 1}
# 21800 {'name0': 'keup', 'name1': 'dignard', 'gt_label': 0, 'DL_classification_score': 0.5640258073806763, 'DL_classification_label': 0, 'RF_classification_label': 0}
# 21900 {'name0': 'altick', 'name1': 'altic', 'gt_label': 1, 'DL_classification_score': 0.9364004373550415, 'DL_classification_label': 1, 'RF_classification_label': 1}
# 22000 {'name0': 'depeel', 'name1': 'depeal', 'gt_label': 1, 'DL_classification_score': 0.9600772857666016, 'DL_classification_label': 1, 'RF_classification_label': 1}
# 22100 {'name0': 'besecker', 'name1': 'beasecker', 'gt_label': 1, 'DL_classification_score': 0.8717676877975464, 'DL_classification_label': 1, 'RF_classification_label': 1}
# 22200 {'name0': 'isherwood', 'name1': 'shewood', 'gt_label': 0, 'DL_classification_score': 0.5389829874038696, 'DL_classification_label': 0, 'RF_classification_label': 0}
# 22300 {'name0': 'mountbatten', 'name1': 'battenberg', 'gt_label': 1, 'DL_classification_score': 0.4871061325073242, 'DL_classification_label': 0, 'RF_classification_label': 1}
# 22400 {'name0': 'elender', 'name1': 'tender', 'gt_label': 0, 'DL_classification_score': 0.628166401386261, 'DL_classification_label': 0, 'RF_classification_label': 0}
# 22500 {'name0': 'walbourne', 'name1': 'prye', 'gt_label': 0, 'DL_classification_score': 0.40656266212463377, 'DL_classification_label': 0, 'RF_classification_label': 0}
# 22600 {'name0': 'rosindale', 'name1': 'rosendale', 'gt_label': 1, 'DL_classification_score': 0.9666900753974914, 'DL_classification_label': 1, 'RF_classification_label': 1}
# 22700 {'name0': 'narlock', 'name1': 'narloch', 'gt_label': 1, 'DL_classification_score': 0.9584150433540344, 'DL_classification_label': 1, 'RF_classification_label': 1}
# 22800 {'name0': 'wolfe', 'name1': 'wolf', 'gt_label': 1, 'DL_classification_score': 0.9450795531272889, 'DL_classification_label': 1, 'RF_classification_label': 1}
# 22900 {'name0': 'paluch', 'name1': 'paluck', 'gt_label': 1, 'DL_classification_score': 0.9545986533164978, 'DL_classification_label': 1, 'RF_classification_label': 1}
# 23000 {'name0': 'hockstatter', 'name1': 'mcgeoghegan', 'gt_label': 0, 'DL_classification_score': 0.4300967514514923, 'DL_classification_label': 0, 'RF_classification_label': 0}
# 23100 {'name0': 'bills', 'name1': 'billson', 'gt_label': 0, 'DL_classification_score': 0.49816675782203673, 'DL_classification_label': 0, 'RF_classification_label': 0}
# 23200 {'name0': 'schulfer', 'name1': 'noblin', 'gt_label': 0, 'DL_classification_score': 0.48789274096488955, 'DL_classification_label': 0, 'RF_classification_label': 0}
# 23300 {'name0': 'brierly', 'name1': 'brierley', 'gt_label': 1, 'DL_classification_score': 0.9823865771293641, 'DL_classification_label': 1, 'RF_classification_label': 1}
# 23400 {'name0': 'zephier', 'name1': 'frase', 'gt_label': 0, 'DL_classification_score': 0.4707788109779358, 'DL_classification_label': 0, 'RF_classification_label': 0}
# 23500 {'name0': 'wickelman', 'name1': 'renne', 'gt_label': 0, 'DL_classification_score': 0.5328492879867553, 'DL_classification_label': 0, 'RF_classification_label': 0}
# 23600 {'name0': 'mansberger', 'name1': 'mansbarger', 'gt_label': 1, 'DL_classification_score': 0.9763023257255554, 'DL_classification_label': 1, 'RF_classification_label': 1}
# 23700 {'name0': 'millerd', 'name1': 'millier', 'gt_label': 0, 'DL_classification_score': 0.6653925895690918, 'DL_classification_label': 0, 'RF_classification_label': 0}
# 23800 {'name0': 'saylors', 'name1': 'sailors', 'gt_label': 1, 'DL_classification_score': 0.8927107810974121, 'DL_classification_label': 1, 'RF_classification_label': 1}
# 23900 {'name0': 'shippen', 'name1': 'whippel', 'gt_label': 0, 'DL_classification_score': 0.4430654048919678, 'DL_classification_label': 0, 'RF_classification_label': 0}
# 24000 {'name0': 'nefzger', 'name1': 'brousson', 'gt_label': 0, 'DL_classification_score': 0.5413417339324951, 'DL_classification_label': 0, 'RF_classification_label': 0}
# 24100 {'name0': 'anaya', 'name1': 'lindenmier', 'gt_label': 0, 'DL_classification_score': 0.5558795034885406, 'DL_classification_label': 0, 'RF_classification_label': 0}
# 24200 {'name0': 'crain', 'name1': 'crane', 'gt_label': 1, 'DL_classification_score': 0.8497653007507324, 'DL_classification_label': 1, 'RF_classification_label': 1}
# 24300 {'name0': 'petrangelo', 'name1': 'kneisle', 'gt_label': 0, 'DL_classification_score': 0.5815637052059174, 'DL_classification_label': 0, 'RF_classification_label': 0}
# 24400 {'name0': 'dimaggio', 'name1': 'demaggio', 'gt_label': 1, 'DL_classification_score': 0.9530532360076904, 'DL_classification_label': 1, 'RF_classification_label': 1}
# 24500 {'name0': 'pollison', 'name1': 'woolison', 'gt_label': 0, 'DL_classification_score': 0.5409852564334869, 'DL_classification_label': 0, 'RF_classification_label': 0}
# 24600 {'name0': 'dieckmann', 'name1': 'blaize', 'gt_label': 0, 'DL_classification_score': 0.5511248886585236, 'DL_classification_label': 0, 'RF_classification_label': 0}
# 24700 {'name0': 'ofallon', 'name1': 'armstone', 'gt_label': 0, 'DL_classification_score': 0.4205224931240082, 'DL_classification_label': 0, 'RF_classification_label': 0}
# 24800 {'name0': 'dorcett', 'name1': 'cadarette', 'gt_label': 0, 'DL_classification_score': 0.5665545642375946, 'DL_classification_label': 0, 'RF_classification_label': 0}
# 24900 {'name0': 'proudlove', 'name1': 'wambsgans', 'gt_label': 0, 'DL_classification_score': 0.46481955647468565, 'DL_classification_label': 0, 'RF_classification_label': 0}
# 25000 {'name0': 'canden', 'name1': 'canthen', 'gt_label': 0, 'DL_classification_score': 0.49736409783363345, 'DL_classification_label': 0, 'RF_classification_label': 0}
# 25100 {'name0': 'baskervill', 'name1': 'mouldy', 'gt_label': 0, 'DL_classification_score': 0.5486003935337067, 'DL_classification_label': 0, 'RF_classification_label': 0}
# 25200 {'name0': 'klingelhofer', 'name1': 'panek', 'gt_label': 0, 'DL_classification_score': 0.5556470394134522, 'DL_classification_label': 0, 'RF_classification_label': 0}
# 25300 {'name0': 'feath', 'name1': 'bartles', 'gt_label': 0, 'DL_classification_score': 0.4722018539905548, 'DL_classification_label': 0, 'RF_classification_label': 0}
# 25400 {'name0': 'deligny', 'name1': 'bidon', 'gt_label': 1, 'DL_classification_score': 0.5156579852104187, 'DL_classification_label': 0, 'RF_classification_label': 1}
# 25500 {'name0': 'collenson', 'name1': 'tollefson', 'gt_label': 0, 'DL_classification_score': 0.536843079328537, 'DL_classification_label': 0, 'RF_classification_label': 0}
# 25600 {'name0': 'widows', 'name1': 'colyn', 'gt_label': 0, 'DL_classification_score': 0.47668113708496096, 'DL_classification_label': 0, 'RF_classification_label': 0}
# 25700 {'name0': 'codwise', 'name1': 'leiger', 'gt_label': 0, 'DL_classification_score': 0.5173540651798249, 'DL_classification_label': 0, 'RF_classification_label': 0}
# 25800 {'name0': 'butwell', 'name1': 'buttwell', 'gt_label': 1, 'DL_classification_score': 0.9217654824256897, 'DL_classification_label': 1, 'RF_classification_label': 1}
# 25900 {'name0': 'vieira', 'name1': 'vierra', 'gt_label': 1, 'DL_classification_score': 0.9160508990287781, 'DL_classification_label': 1, 'RF_classification_label': 1}
# 26000 {'name0': 'timms', 'name1': 'tims', 'gt_label': 1, 'DL_classification_score': 0.9152875781059265, 'DL_classification_label': 1, 'RF_classification_label': 1}
# 26100 {'name0': 'mclaran', 'name1': 'mclean', 'gt_label': 0, 'DL_classification_score': 0.5390194356441498, 'DL_classification_label': 0, 'RF_classification_label': 0}
# 26200 {'name0': 'petrello', 'name1': 'philip', 'gt_label': 0, 'DL_classification_score': 0.5544186890125274, 'DL_classification_label': 0, 'RF_classification_label': 0}
# 26300 {'name0': 'loga', 'name1': 'moscho', 'gt_label': 0, 'DL_classification_score': 0.5726843416690827, 'DL_classification_label': 0, 'RF_classification_label': 0}
# 26400 {'name0': 'headlee', 'name1': 'headley', 'gt_label': 1, 'DL_classification_score': 0.8196899175643921, 'DL_classification_label': 1, 'RF_classification_label': 1}
# 26500 {'name0': 'omlid', 'name1': 'wobig', 'gt_label': 0, 'DL_classification_score': 0.5071800947189331, 'DL_classification_label': 0, 'RF_classification_label': 0}
# 26600 {'name0': 'rokes', 'name1': 'roakes', 'gt_label': 1, 'DL_classification_score': 0.8777936100959778, 'DL_classification_label': 1, 'RF_classification_label': 1}
# 26700 {'name0': 'ruskey', 'name1': 'vennie', 'gt_label': 0, 'DL_classification_score': 0.45027526617050173, 'DL_classification_label': 0, 'RF_classification_label': 0}
# 26800 {'name0': 'mellein', 'name1': 'pelson', 'gt_label': 0, 'DL_classification_score': 0.4835655927658081, 'DL_classification_label': 0, 'RF_classification_label': 0}
# 26900 {'name0': 'willmott', 'name1': 'wilmott', 'gt_label': 1, 'DL_classification_score': 0.970557975769043, 'DL_classification_label': 1, 'RF_classification_label': 1}
# 27000 {'name0': 'schleger', 'name1': 'lonberger', 'gt_label': 0, 'DL_classification_score': 0.48230881690979005, 'DL_classification_label': 0, 'RF_classification_label': 0}
# 27100 {'name0': 'begent', 'name1': 'berentz', 'gt_label': 0, 'DL_classification_score': 0.5553664147853852, 'DL_classification_label': 0, 'RF_classification_label': 0}
# 27200 {'name0': 'futcher', 'name1': 'titcher', 'gt_label': 0, 'DL_classification_score': 0.5722352623939514, 'DL_classification_label': 0, 'RF_classification_label': 0}
# 27300 {'name0': 'bygrave', 'name1': 'bygraves', 'gt_label': 1, 'DL_classification_score': 0.9316342830657959, 'DL_classification_label': 1, 'RF_classification_label': 1}
# 27400 {'name0': 'gabbie', 'name1': 'oehmann', 'gt_label': 0, 'DL_classification_score': 0.5066411375999451, 'DL_classification_label': 0, 'RF_classification_label': 0}
# 27500 {'name0': 'rummler', 'name1': 'simmler', 'gt_label': 0, 'DL_classification_score': 0.5348448991775513, 'DL_classification_label': 0, 'RF_classification_label': 0}
# 27600 {'name0': 'elzner', 'name1': 'zeltner', 'gt_label': 0, 'DL_classification_score': 0.5729173243045806, 'DL_classification_label': 0, 'RF_classification_label': 0}
# 27700 {'name0': 'wiederholt', 'name1': 'weiderholt', 'gt_label': 1, 'DL_classification_score': 0.9989789843559265, 'DL_classification_label': 1, 'RF_classification_label': 1}
# 27800 {'name0': 'boutchyard', 'name1': 'fouchard', 'gt_label': 0, 'DL_classification_score': 0.5048085808753967, 'DL_classification_label': 0, 'RF_classification_label': 0}
# 27900 {'name0': 'veno', 'name1': 'vieno', 'gt_label': 0, 'DL_classification_score': 0.7781296968460083, 'DL_classification_label': 0, 'RF_classification_label': 0}
# 28000 {'name0': 'pulse', 'name1': 'dollson', 'gt_label': 0, 'DL_classification_score': 0.4853422582149506, 'DL_classification_label': 0, 'RF_classification_label': 0}
# 28100 {'name0': 'banfill', 'name1': 'banfil', 'gt_label': 1, 'DL_classification_score': 0.9613878607749939, 'DL_classification_label': 1, 'RF_classification_label': 1}
# 28200 {'name0': 'nemmers', 'name1': 'nimmers', 'gt_label': 1, 'DL_classification_score': 0.9089423775672912, 'DL_classification_label': 1, 'RF_classification_label': 1}
# ...
# 66500 {'name0': 'boneck', 'name1': 'steeve', 'gt_label': 0, 'DL_classification_score': 0.5204293191432953, 'DL_classification_label': 0, 'RF_classification_label': 0}
# 66600 {'name0': 'cleverly', 'name1': 'cleverley', 'gt_label': 1, 'DL_classification_score': 0.9898788928985596, 'DL_classification_label': 1, 'RF_classification_label': 1}
# 66700 {'name0': 'tatti', 'name1': 'tatty', 'gt_label': 0, 'DL_classification_score': 0.9097389459609986, 'DL_classification_label': 1, 'RF_classification_label': 0}
# 66800 {'name0': 'priep', 'name1': 'enston', 'gt_label': 0, 'DL_classification_score': 0.44159731864929197, 'DL_classification_label': 0, 'RF_classification_label': 0}
# 66900 {'name0': 'stooksbury', 'name1': 'stooksberry', 'gt_label': 1, 'DL_classification_score': 0.9468601226806641, 'DL_classification_label': 1, 'RF_classification_label': 1}
# 67000 {'name0': 'kretschmann', 'name1': 'kretschman', 'gt_label': 1, 'DL_classification_score': 0.9827351450920105, 'DL_classification_label': 1, 'RF_classification_label': 1}
# 67100 {'name0': 'wullenwaber', 'name1': 'wullenweber', 'gt_label': 1, 'DL_classification_score': 0.9952004432678223, 'DL_classification_label': 1, 'RF_classification_label': 1}
# 67200 {'name0': 'dougall', 'name1': 'downall', 'gt_label': 0, 'DL_classification_score': 0.5705863773822785, 'DL_classification_label': 0, 'RF_classification_label': 0}
# 67300 {'name0': 'challender', 'name1': 'chalender', 'gt_label': 1, 'DL_classification_score': 0.93082035779953, 'DL_classification_label': 1, 'RF_classification_label': 1}
# 67400 {'name0': 'aperson', 'name1': 'lawerson', 'gt_label': 0, 'DL_classification_score': 0.5363053679466248, 'DL_classification_label': 0, 'RF_classification_label': 0}
# 67500 {'name0': 'creedy', 'name1': 'goosmann', 'gt_label': 0, 'DL_classification_score': 0.5513007998466491, 'DL_classification_label': 0, 'RF_classification_label': 0}
# 67600 {'name0': 'hegrenes', 'name1': 'hageness', 'gt_label': 1, 'DL_classification_score': 0.5207062661647797, 'DL_classification_label': 0, 'RF_classification_label': 1}
# 67700 {'name0': 'taysom', 'name1': 'tayson', 'gt_label': 1, 'DL_classification_score': 0.8788479447364808, 'DL_classification_label': 1, 'RF_classification_label': 1}
# 67800 {'name0': 'praiswater', 'name1': 'praisewater', 'gt_label': 1, 'DL_classification_score': 0.972563898563385, 'DL_classification_label': 1, 'RF_classification_label': 1}
# 67900 {'name0': 'widner', 'name1': 'widener', 'gt_label': 1, 'DL_classification_score': 0.9670326352119446, 'DL_classification_label': 1, 'RF_classification_label': 1}
# 68000 {'name0': 'kaloostian', 'name1': 'fatheree', 'gt_label': 0, 'DL_classification_score': 0.5912986159324646, 'DL_classification_label': 0, 'RF_classification_label': 0}
# 68100 {'name0': 'hakins', 'name1': 'jackins', 'gt_label': 0, 'DL_classification_score': 0.5898225486278534, 'DL_classification_label': 0, 'RF_classification_label': 0}
# 68200 {'name0': 'favorite', 'name1': 'wurmser', 'gt_label': 0, 'DL_classification_score': 0.5078347146511077, 'DL_classification_label': 0, 'RF_classification_label': 0}
# 68300 {'name0': 'frueh', 'name1': 'fruch', 'gt_label': 1, 'DL_classification_score': 0.7997146606445312, 'DL_classification_label': 0, 'RF_classification_label': 1}
# 68400 {'name0': 'digre', 'name1': 'becktel', 'gt_label': 0, 'DL_classification_score': 0.4119047999382019, 'DL_classification_label': 0, 'RF_classification_label': 0}
# 68500 {'name0': 'feek', 'name1': 'dustow', 'gt_label': 0, 'DL_classification_score': 0.5040894865989685, 'DL_classification_label': 0, 'RF_classification_label': 0}
# 68600 {'name0': 'klontz', 'name1': 'kloutz', 'gt_label': 1, 'DL_classification_score': 0.8691542506217956, 'DL_classification_label': 1, 'RF_classification_label': 1}
# 68700 {'name0': 'leseman', 'name1': 'riseman', 'gt_label': 0, 'DL_classification_score': 0.43477078676223757, 'DL_classification_label': 0, 'RF_classification_label': 0}
# 68800 {'name0': 'sprowles', 'name1': 'sprowls', 'gt_label': 1, 'DL_classification_score': 0.9804736256599427, 'DL_classification_label': 1, 'RF_classification_label': 1}
# 68900 {'name0': 'mccanney', 'name1': 'mchanney', 'gt_label': 0, 'DL_classification_score': 0.8447095036506653, 'DL_classification_label': 1, 'RF_classification_label': 1}
# 69000 {'name0': 'serovy', 'name1': 'lunceford', 'gt_label': 0, 'DL_classification_score': 0.4975481927394867, 'DL_classification_label': 0, 'RF_classification_label': 0}
# 69100 {'name0': 'tetsell', 'name1': 'weighley', 'gt_label': 0, 'DL_classification_score': 0.5325801134109497, 'DL_classification_label': 0, 'RF_classification_label': 0}
# 69200 {'name0': 'louser', 'name1': 'lauser', 'gt_label': 1, 'DL_classification_score': 0.9307348966598511, 'DL_classification_label': 1, 'RF_classification_label': 1}
# 69300 {'name0': 'billingslea', 'name1': 'lelean', 'gt_label': 0, 'DL_classification_score': 0.46072736382484436, 'DL_classification_label': 0, 'RF_classification_label': 0}
# 69400 {'name0': 'cohoe', 'name1': 'coho', 'gt_label': 1, 'DL_classification_score': 0.8724895238876342, 'DL_classification_label': 1, 'RF_classification_label': 1}
# 69500 {'name0': 'cisco', 'name1': 'sciscoe', 'gt_label': 0, 'DL_classification_score': 0.6808079361915589, 'DL_classification_label': 0, 'RF_classification_label': 0}
# 69600 {'name0': 'blackadder', 'name1': 'boecking', 'gt_label': 0, 'DL_classification_score': 0.44505528807640077, 'DL_classification_label': 0, 'RF_classification_label': 0}
# 69700 {'name0': 'graeber', 'name1': 'dieke', 'gt_label': 0, 'DL_classification_score': 0.4354417622089386, 'DL_classification_label': 0, 'RF_classification_label': 0}
# 69800 {'name0': 'bortfeld', 'name1': 'ruvis', 'gt_label': 0, 'DL_classification_score': 0.5496927201747894, 'DL_classification_label': 0, 'RF_classification_label': 0}
# 69900 {'name0': 'harrell', 'name1': 'fraijo', 'gt_label': 0, 'DL_classification_score': 0.5430880069732666, 'DL_classification_label': 0, 'RF_classification_label': 0}
# 70000 {'name0': 'mclarry', 'name1': 'mclroy', 'gt_label': 0, 'DL_classification_score': 0.8376704931259156, 'DL_classification_label': 1, 'RF_classification_label': 0}
# 70100 {'name0': 'aydelotte', 'name1': 'urfer', 'gt_label': 0, 'DL_classification_score': 0.49719877243041993, 'DL_classification_label': 0, 'RF_classification_label': 0}
# 70200 {'name0': 'ogline', 'name1': 'broocks', 'gt_label': 0, 'DL_classification_score': 0.4948875069618225, 'DL_classification_label': 0, 'RF_classification_label': 0}
# 70300 {'name0': 'nimbar', 'name1': 'rearic', 'gt_label': 0, 'DL_classification_score': 0.5245361804962159, 'DL_classification_label': 0, 'RF_classification_label': 0}
# 70400 {'name0': 'muenkel', 'name1': 'munkel', 'gt_label': 1, 'DL_classification_score': 0.9416882991790771, 'DL_classification_label': 1, 'RF_classification_label': 1}
# 70500 {'name0': 'dellenback', 'name1': 'kallenbach', 'gt_label': 0, 'DL_classification_score': 0.45236521363258364, 'DL_classification_label': 0, 'RF_classification_label': 0}
# 70600 {'name0': 'banhart', 'name1': 'donta', 'gt_label': 0, 'DL_classification_score': 0.5347803831100464, 'DL_classification_label': 0, 'RF_classification_label': 0}
# 70700 {'name0': 'garies', 'name1': 'cundle', 'gt_label': 0, 'DL_classification_score': 0.5275298118591308, 'DL_classification_label': 0, 'RF_classification_label': 0}
# 70800 {'name0': 'engelking', 'name1': 'engleking', 'gt_label': 1, 'DL_classification_score': 0.9692839622497559, 'DL_classification_label': 1, 'RF_classification_label': 1}
# 70900 {'name0': 'wauson', 'name1': 'wanson', 'gt_label': 1, 'DL_classification_score': 0.9009538054466247, 'DL_classification_label': 1, 'RF_classification_label': 1}
# 71000 {'name0': 'ladusau', 'name1': 'ladusan', 'gt_label': 1, 'DL_classification_score': 0.8835459232330323, 'DL_classification_label': 1, 'RF_classification_label': 1}
# 71100 {'name0': 'eifler', 'name1': 'feisler', 'gt_label': 0, 'DL_classification_score': 0.5351472973823548, 'DL_classification_label': 0, 'RF_classification_label': 0}
# 71200 {'name0': 'pierro', 'name1': 'ca', 'gt_label': 0, 'DL_classification_score': 0.45483153462409975, 'DL_classification_label': 0, 'RF_classification_label': 0}
# 71300 {'name0': 'niller', 'name1': 'heesacker', 'gt_label': 0, 'DL_classification_score': 0.5785256147384643, 'DL_classification_label': 0, 'RF_classification_label': 0}
# 71400 {'name0': 'snoddon', 'name1': 'snodden', 'gt_label': 1, 'DL_classification_score': 0.9558682918548584, 'DL_classification_label': 1, 'RF_classification_label': 1}
# 71500 {'name0': 'creag', 'name1': 'lunke', 'gt_label': 0, 'DL_classification_score': 0.4998504400253296, 'DL_classification_label': 0, 'RF_classification_label': 0}
# 71600 {'name0': 'polgrean', 'name1': 'polgreen', 'gt_label': 1, 'DL_classification_score': 0.9737200856208801, 'DL_classification_label': 1, 'RF_classification_label': 1}
# 71700 {'name0': 'steuck', 'name1': 'janiec', 'gt_label': 0, 'DL_classification_score': 0.41925826072692873, 'DL_classification_label': 0, 'RF_classification_label': 0}
# 71800 {'name0': 'beganson', 'name1': 'ludby', 'gt_label': 0, 'DL_classification_score': 0.5172728896141052, 'DL_classification_label': 0, 'RF_classification_label': 0}
# 71900 {'name0': 'hawkesford', 'name1': 'hawksford', 'gt_label': 1, 'DL_classification_score': 0.9742393016815185, 'DL_classification_label': 1, 'RF_classification_label': 1}
# 72000 {'name0': 'langlitz', 'name1': 'rediate', 'gt_label': 0, 'DL_classification_score': 0.45304741263389586, 'DL_classification_label': 0, 'RF_classification_label': 0}
# 72100 {'name0': 'ardrey', 'name1': 'marbrey', 'gt_label': 0, 'DL_classification_score': 0.5059475421905517, 'DL_classification_label': 0, 'RF_classification_label': 0}
# 72200 {'name0': 'hanman', 'name1': 'vaneman', 'gt_label': 0, 'DL_classification_score': 0.4651987850666046, 'DL_classification_label': 0, 'RF_classification_label': 0}
# 72300 {'name0': 'scammell', 'name1': 'scammel', 'gt_label': 1, 'DL_classification_score': 0.9595247626304626, 'DL_classification_label': 1, 'RF_classification_label': 1}
# 72400 {'name0': 'sivey', 'name1': 'sharrat', 'gt_label': 0, 'DL_classification_score': 0.511813473701477, 'DL_classification_label': 0, 'RF_classification_label': 0}
# 72500 {'name0': 'mushrush', 'name1': 'musrush', 'gt_label': 0, 'DL_classification_score': 0.6819150686264038, 'DL_classification_label': 0, 'RF_classification_label': 0}
# 72600 {'name0': 'linberg', 'name1': 'lofberg', 'gt_label': 0, 'DL_classification_score': 0.47117852568626406, 'DL_classification_label': 0, 'RF_classification_label': 0}
# 72700 {'name0': 'tolley', 'name1': 'tolly', 'gt_label': 1, 'DL_classification_score': 0.98381507396698, 'DL_classification_label': 1, 'RF_classification_label': 1}
# 72800 {'name0': 'fame', 'name1': 'fate', 'gt_label': 0, 'DL_classification_score': 0.4475294828414917, 'DL_classification_label': 0, 'RF_classification_label': 0}
# 72900 {'name0': 'nedreau', 'name1': 'verreau', 'gt_label': 0, 'DL_classification_score': 0.4952614545822144, 'DL_classification_label': 0, 'RF_classification_label': 0}
# 73000 {'name0': 'worsford', 'name1': 'baldington', 'gt_label': 0, 'DL_classification_score': 0.5331507503986359, 'DL_classification_label': 0, 'RF_classification_label': 0}
# 73100 {'name0': 'shankle', 'name1': 'shankles', 'gt_label': 1, 'DL_classification_score': 0.9102488279342651, 'DL_classification_label': 1, 'RF_classification_label': 1}
# 73200 {'name0': 'quaife', 'name1': 'quaif', 'gt_label': 1, 'DL_classification_score': 0.9673509478569031, 'DL_classification_label': 1, 'RF_classification_label': 1}
# 73300 {'name0': 'lavalleur', 'name1': 'froeliger', 'gt_label': 0, 'DL_classification_score': 0.5977458953857422, 'DL_classification_label': 0, 'RF_classification_label': 0}
# 73400 {'name0': 'bertell', 'name1': 'bittell', 'gt_label': 0, 'DL_classification_score': 0.46555396914482117, 'DL_classification_label': 0, 'RF_classification_label': 0}
# 73500 {'name0': 'jeanotte', 'name1': 'jeannotte', 'gt_label': 1, 'DL_classification_score': 0.9505088329315186, 'DL_classification_label': 1, 'RF_classification_label': 1}
# 73600 {'name0': 'bomgarner', 'name1': 'lussen', 'gt_label': 0, 'DL_classification_score': 0.5018584966659546, 'DL_classification_label': 0, 'RF_classification_label': 0}
# 73700 {'name0': 'caldell', 'name1': 'ayrs', 'gt_label': 0, 'DL_classification_score': 0.5038582801818847, 'DL_classification_label': 0, 'RF_classification_label': 0}
# 73800 {'name0': 'robbs', 'name1': 'robs', 'gt_label': 0, 'DL_classification_score': 0.7810211777687073, 'DL_classification_label': 1, 'RF_classification_label': 1}
# 73900 {'name0': 'hatford', 'name1': 'sanford', 'gt_label': 0, 'DL_classification_score': 0.5465218186378479, 'DL_classification_label': 0, 'RF_classification_label': 0}
# 74000 {'name0': 'baldock', 'name1': 'beldock', 'gt_label': 0, 'DL_classification_score': 0.8554090857505798, 'DL_classification_label': 1, 'RF_classification_label': 1}
# 74100 {'name0': 'clemmen', 'name1': 'kittrel', 'gt_label': 0, 'DL_classification_score': 0.5517329275608063, 'DL_classification_label': 0, 'RF_classification_label': 0}
# 74200 {'name0': 'freestone', 'name1': 'freeston', 'gt_label': 1, 'DL_classification_score': 0.9788387775421142, 'DL_classification_label': 1, 'RF_classification_label': 1}
# 74300 {'name0': 'pekarske', 'name1': 'pikarski', 'gt_label': 0, 'DL_classification_score': 0.8584254145622253, 'DL_classification_label': 1, 'RF_classification_label': 0}
# 74400 {'name0': 'berkbigler', 'name1': 'berkbuegler', 'gt_label': 1, 'DL_classification_score': 0.922354233264923, 'DL_classification_label': 1, 'RF_classification_label': 1}
# 74500 {'name0': 'fantone', 'name1': 'nanton', 'gt_label': 0, 'DL_classification_score': 0.46837151050567627, 'DL_classification_label': 0, 'RF_classification_label': 0}
# 74600 {'name0': 'probyn', 'name1': 'probin', 'gt_label': 1, 'DL_classification_score': 0.9042428135871887, 'DL_classification_label': 1, 'RF_classification_label': 1}
# 74700 {'name0': 'sligar', 'name1': 'sliger', 'gt_label': 1, 'DL_classification_score': 0.9096558809280395, 'DL_classification_label': 1, 'RF_classification_label': 1}
# 74800 {'name0': 'biesinger', 'name1': 'brenninger', 'gt_label': 0, 'DL_classification_score': 0.44887553453445433, 'DL_classification_label': 0, 'RF_classification_label': 0}
# 74900 {'name0': 'gouldman', 'name1': 'garnette', 'gt_label': 0, 'DL_classification_score': 0.49402694702148436, 'DL_classification_label': 0, 'RF_classification_label': 0}
#            name0       name1  gt_label  DL_classification_score  \
# 0        dessell     pessall         0                 0.472810
# 1        ellgood      elwood         0                 0.644247
# 2         ermann       erman         1                 0.974459
# 3         koland     nowland         0                 0.447516
# 4       radebach     rasbach         0                 0.470515
# ...          ...         ...       ...                      ...
# 74995      eoute      rankle         0                 0.525536
# 74996     dossin      gossin         0                 0.511264
# 74997       izor  nordenberg         0                 0.499483
# 74998    schnars    schnarrs         1                 0.943826
# 74999  warnement   warnament         1                 0.964682
#
#        DL_classification_label  RF_classification_label
# 0                            0                        0
# 1                            0                        0
# 2                            1                        1
# 3                            0                        0
# 4                            0                        0
# ...                        ...                      ...
# 74995                        0                        0
# 74996                        0                        0
# 74997                        0                        0
# 74998                        1                        1
# 74999                        1                        1
#
# [75000 rows x 6 columns]

# %% [markdown]
# # 6. Create additional data for the result set
# DL Bucket, RF bucket, concatenated bucket

# %%
def calculate_bucket(gt, pred):
    if gt == 1 and pred == 1:
        return "tp"
    elif gt == 1 and pred == 0:
        return "fn"
    elif gt == 0 and pred == 1:
        return "fp"
    elif gt == 0 and pred == 0:
        return "tn"
    
results_set["DL_bucket"] = [calculate_bucket(x, y) for x, y in results_set[["gt_label", "DL_classification_label"]].itertuples(index=False)]
results_set["RF_bucket"] = [calculate_bucket(x, y) for x, y in results_set[["gt_label", "RF_classification_label"]].itertuples(index=False)]
results_set["concat_bucket"] = [x + "_" + y for x, y in results_set[["DL_bucket", "RF_bucket"]].itertuples(index=False)]

results_set
# Out:
#            name0       name1  gt_label  DL_classification_score  \
# 0        dessell     pessall         0                 0.472810
# 1        ellgood      elwood         0                 0.644247
# 2         ermann       erman         1                 0.974459
# 3         koland     nowland         0                 0.447516
# 4       radebach     rasbach         0                 0.470515
# ...          ...         ...       ...                      ...
# 74995      eoute      rankle         0                 0.525536
# 74996     dossin      gossin         0                 0.511264
# 74997       izor  nordenberg         0                 0.499483
# 74998    schnars    schnarrs         1                 0.943826
# 74999  warnement   warnament         1                 0.964682
#
#        DL_classification_label  RF_classification_label DL_bucket RF_bucket  \
# 0                            0                        0        tn        tn
# 1                            0                        0        tn        tn
# 2                            1                        1        tp        tp
# 3                            0                        0        tn        tn
# 4                            0                        0        tn        tn
# ...                        ...                      ...       ...       ...
# 74995                        0                        0        tn        tn
# 74996                        0                        0        tn        tn
# 74997                        0                        0        tn        tn
# 74998                        1                        1        tp        tp
# 74999                        1                        1        tp        tp
#
#       concat_bucket
# 0             tn_tn
# 1             tn_tn
# 2             tp_tp
# 3             tn_tn
# 4             tn_tn
# ...             ...
# 74995         tn_tn
# 74996         tn_tn
# 74997         tn_tn
# 74998         tp_tp
# 74999         tp_tp
#
# [75000 rows x 9 columns]

# %% [markdown]
# # 7. Save to .csv

# %%
results_set.to_csv(os.path.join(csv_save_path, run_name + "_" + result_set + ".csv"))
